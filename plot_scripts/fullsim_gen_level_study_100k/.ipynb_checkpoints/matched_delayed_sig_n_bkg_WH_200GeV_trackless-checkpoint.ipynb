# %%
import ROOT as rt
import csv
import re
import sys
import collections
from collections import OrderedDict
import uproot
import numpy as np
import time
import numba
from numba import jit
from matplotlib import pyplot as plt
from numpy import linalg as LA
from ROOT import TLorentzVector
from array import array
# import PyTEX
import os

import math

sys.path.append('/storage/user/jmao/gpu/jmao/cms-llp/delayed_jet_analyzer/lib/')

from histo_utilities import create_TH1D, create_TH2D, create_TGraph,std_color_list

import CMS_lumi, tdrstyle 
tdrstyle.setTDRStyle()
CMS_lumi.writeExtraText = 1
CMS_lumi.extraText = "     Simulation Preliminary"

     
print(sys.version)
# Out:
# 3.6.8 (default, Aug  7 2019, 17:28:10)
# [GCC 4.8.5 20150623 (Red Hat 4.8.5-39)]

# %% [markdown]
# # Inputs

# %%
#labels
tags = []
tags = [
        'W(lv)Jets, background',
        'W(lv)H(bb), C1N2, 200 GeV, 150 GeV, 1 m',
        'W(lv)H(bb), C1N2, 200 GeV, 1 GeV, 1 m',
        'W(lv)H(bb), TwinHiggs, 125 GeV, 40 GeV, 1 m',
        ]


# directory
home_dir = '/mnt/hadoop/store/group/phys_exotica/jmao/susy_llp/llp_analyzer/'


# file names

fnames = {}

fnames['W(lv)H(bb), C1N2, 200 GeV, 150 GeV, 1 m'] = 'testrun/RunIIFall17_x1n2-n1-wlv-hbb_mchi200_mlsp150_pl1000_ev100000_fullsim_signal_aod_llp_analyzer.root'
fnames['W(lv)H(bb), C1N2, 200 GeV, 1 GeV, 1 m'] =  'testrun/RunIIFall17_x1n2-n1-wlv-hbb_mh200_pl1000_ev100000_fullsim_signal_aod_llp_analyzer.root'
fnames['W(lv)H(bb), TwinHiggs, 125 GeV, 40 GeV, 1 m'] = 'testrun/WH_HToSSTobbbb_WToLNu_MH-125_MS-40_ctauS-1000_TuneCUETP8M1_13TeV-powheg-pythia8_llp_analyzer.root' 
fnames['W(lv)Jets, background'] = 'WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_v6-v1_v1_v1/WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_v6-v1_v1_v1_Job0_Of_16.root'

# output plots directory
out_dir = '/storage/user/jmao/gpu/jmao/cms-llp/plots/20191022/'

 
# colors
cols = {}

cols['W(lv)H(bb), C1N2, 200 GeV, 150 GeV, 1 m'] = 215 
cols['W(lv)H(bb), C1N2, 200 GeV, 1 GeV, 1 m'] = 207  
cols['W(lv)H(bb), TwinHiggs, 125 GeV, 40 GeV, 1 m'] = 221 
cols['W(lv)Jets, background'] = 209 


#styles
stys = {}

stys['W(lv)H(bb), C1N2, 200 GeV, 150 GeV, 1 m'] = 3 
stys['W(lv)H(bb), C1N2, 200 GeV, 1 GeV, 1 m'] = 4  
stys['W(lv)H(bb), TwinHiggs, 125 GeV, 40 GeV, 1 m'] = 2 
stys['W(lv)Jets, background'] = 1

 

# get all the trees
tree = OrderedDict()

for tag in tags:
    print(home_dir+fnames[tag])
 
    root_dir = uproot.open(home_dir+fnames[tag]) 
    tree[tag] = root_dir['SusyLLPTree']
 
    print ('Open ready')
    print(tag)
    print ('Tree ready') 
    print(tree[tag], tree)
    v = tree[tag]
#     llp_d_pid = v['gLLP_daughter_pid'].array()
#     print(llp_d_pid[:10])
    jet_amax = v['jetGammaMax_ET'].array()
    print(jet_amax[:10])
    if 'back' not in tag:
        calo_jet_amax = v['gLLP0_EB'].array()
        print(calo_jet_amax[:10])
# Out:
# /mnt/hadoop/store/group/phys_exotica/jmao/susy_llp/llp_analyzer/WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_v6-v1_v1_v1/WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_v6-v1_v1_v1_Job0_Of_16.root
# Open ready
# W(lv)Jets, background
# Tree ready
# <TTree b'SusyLLPTree' at 0x7fac54dbdef0> OrderedDict([('W(lv)Jets, background', <TTree b'SusyLLPTree' at 0x7fac54dbdef0>)])
# [[] [] [0.320261 0.063849434 0.20987378] ... [] [] [0.020599715]]
# /mnt/hadoop/store/group/phys_exotica/jmao/susy_llp/llp_analyzer/testrun/RunIIFall17_x1n2-n1-wlv-hbb_mchi200_mlsp150_pl1000_ev100000_fullsim_signal_aod_llp_analyzer.root
# Open ready
# W(lv)H(bb), C1N2, 200 GeV, 150 GeV, 1 m
# Tree ready
# <TTree b'SusyLLPTree' at 0x7fac46d32400> OrderedDict([('W(lv)Jets, background', <TTree b'SusyLLPTree' at 0x7fac54dbdef0>), ('W(lv)H(bb), C1N2, 200 GeV, 150 GeV, 1 m', <TTree b'SusyLLPTree' at 0x7fac46d32400>)])
# [[] [0.46289212 0.17120078] [0.09560327 0.85191566 0.08972866] ... [0.093980454] [0.0 0.69223166] [0.7016673]]
# [ True False  True False False False False False  True False]
# /mnt/hadoop/store/group/phys_exotica/jmao/susy_llp/llp_analyzer/testrun/RunIIFall17_x1n2-n1-wlv-hbb_mh200_pl1000_ev100000_fullsim_signal_aod_llp_analyzer.root
# Open ready
# W(lv)H(bb), C1N2, 200 GeV, 1 GeV, 1 m
# Tree ready
# <TTree b'SusyLLPTree' at 0x7fac46ae10b8> OrderedDict([('W(lv)Jets, background', <TTree b'SusyLLPTree' at 0x7fac54dbdef0>), ('W(lv)H(bb), C1N2, 200 GeV, 150 GeV, 1 m', <TTree b'SusyLLPTree' at 0x7fac46d32400>), ('W(lv)H(bb), C1N2, 200 GeV, 1 GeV, 1 m', <TTree b'SusyLLPTree' at 0x7fac46ae10b8>)])
# [[0.11905965] [0.45596537 0.43482432 0.023286592 0.0 0.16662261] [0.046404634 0.38955608] ... [0.09113078] [0.49727336] [0.1763379 0.05245678]]
# [ True  True False False False False False False False False]
# /mnt/hadoop/store/group/phys_exotica/jmao/susy_llp/llp_analyzer/testrun/WH_HToSSTobbbb_WToLNu_MH-125_MS-40_ctauS-1000_TuneCUETP8M1_13TeV-powheg-pythia8_llp_analyzer.root
# Open ready
# W(lv)H(bb), TwinHiggs, 125 GeV, 40 GeV, 1 m
# Tree ready
# <TTree b'SusyLLPTree' at 0x7fac46be70b8> OrderedDict([('W(lv)Jets, background', <TTree b'SusyLLPTree' at 0x7fac54dbdef0>), ('W(lv)H(bb), C1N2, 200 GeV, 150 GeV, 1 m', <TTree b'SusyLLPTree' at 0x7fac46d32400>), ('W(lv)H(bb), C1N2, 200 GeV, 1 GeV, 1 m', <TTree b'SusyLLPTree' at 0x7fac46ae10b8>), ('W(lv)H(bb), TwinHiggs, 125 GeV, 40 GeV, 1 m', <TTree b'SusyLLPTree' at 0x7fac46be70b8>)])
# [[0.028963976 0.04717658] [0.67492014] [0.026323987] ... [0.018737534 0.55658656 0.7916403 0.0] [0.0 0.0] [0.04235454]]
# [False False  True False  True False  True  True  True  True]

# %% [markdown]
# # pf jet

# %%
import os

out_dir = '/storage/user/jmao/gpu/jmao/cms-llp/plots/20191022/'

print(out_dir)
# os.mkdir(out_dir)
# Out:
# /storage/user/jmao/gpu/jmao/cms-llp/plots/20191022/

# %%
pt_ranges = [[20,30],[30,40],[40,50]]
for pt_range in pt_ranges:
    print(pt_range)    
    pt_str = str(pt_range[0])+'_'+str(pt_range[1])
    print(pt_str)
# Out:
# [20, 30]
# 20_30
# [30, 40]
# 30_40
# [40, 50]
# 40_50

# %% [markdown]
# ## pf jet trackless variables

# %%
# pf jet

acc = 1
acc_or = 1
acc_case = 'barrel'
# acc_case = 'endcap'
# acc_case = 'all'
match = 1
cut = 1 # 1: pt >  pt_cut; 0: pt in pt_range
pt_cut = 0
pt_ranges = [[20,30],[30,40],[40,50]]

if cut:
    print('pt > pt_cut')
    if acc:
        out_dir = out_dir + 'pt_cut_'+str(pt_cut)+'_match_'+str(match)+'_acc_'+str(acc)+'_acc_case_'+acc_case+'_acc_or_'+str(acc_or)+'/'
    else:
        out_dir = out_dir + 'pt_cut_'+str(pt_cut)+'_match_'+str(match)+'_acc_'+str(acc)+'/'
else:
    print('pt in pt_ranges')
    for pt_range in pt_ranges:
        pt_str = str(pt_range[0])+'_'+str(pt_range[1])
    

    
print(out_dir)
os.mkdir(out_dir)

i = 0

pf_jet_pt = {}
pf_jet_time = {}

pf_jet_chef = {}
pf_jet_h_over_e = {}

pf_jet_tmf_et = {}
pf_jet_delta_r = {}
pf_jet_pt_trk = {}

for k,v in tree.items(): 
    print(k,v)
    
    pf_jet_time[k] = []
    pf_jet_chef[k] = []
    pf_jet_h_over_e[k] = []
    pf_jet_tmf_et[k] = []
    pf_jet_delta_r[k] = []
    pf_jet_pt_trk[k] = []
 
    #branches

    time = v['jetTime'].array()
    
    charged_em = v['jetChargedEMEnergyFraction'].array()
    neutral_em = v['jetNeutralEMEnergyFraction'].array()
        
    charged_had = v['jetChargedHadronEnergyFraction'].array()
    neutral_had = v['jetNeutralHadronEnergyFraction'].array()
    
    tmf_et = v['jetGammaMax_ET'].array()
    delta_r = v['jetMinDeltaRPVTracks'].array()
    pt_trk = v['jetPtAllPVTracks'].array()
        
    e = v['jetE'].array()
    pt = v['jetPt'].array()
    eta = v['jetEta'].array()

    basic1_str = np.logical_and(abs(eta)<1.48, pt>pt_cut)

    
    
    # matched requirement
    if 'background' not in k:
        matched0 = v['jet_matched_gLLP0_daughter'].array()
        matched1 = v['jet_matched_gLLP1_daughter'].array()
        matched_str = np.logical_or(matched0==1, matched1==1)

        acc0_eb = v['gLLP0_EB'].array()
        acc1_eb = v['gLLP1_EB'].array() 

        acc1_ee = v['gLLP0_EE'].array()
        acc0_ee = v['gLLP1_EE'].array()

        if acc_or:
            acc_eb_str = np.logical_or(acc0_eb==1, acc1_eb==1)
            acc_ee_str = np.logical_or(acc0_ee==1, acc1_ee==1)
        else:
            acc_eb_str = np.logical_and(acc0_eb==1, acc1_eb==1)
            acc_ee_str = np.logical_and(acc0_ee==1, acc1_ee==1)

        # accepantance requirement
        if acc_case=='barrel':
            acc_str = acc_eb_str
        elif acc_case=='endcap':
            acc_str = acc_ee_str
        elif acc_case=='all':
            acc_str = np.logical_or(acc_eb_str, acc_ee_str)    
    
    
    if 'background' in k:
        basic_str = basic1_str
    elif not match and not acc:
        basic_str = basic1_str
    elif match and not acc:
        basic_str = np.logical_and(basic1_str, matched_str)
    elif not match and acc:
        basic_str = np.logical_and(basic1_str, acc_str)
    elif match and acc:
        basic2_str = np.logical_and(matched_str, acc_str)
        basic_str = np.logical_and(basic1_str, basic2_str)
 
    # variables        
    
    j_pt = pt[basic_str]
    j_time = time[basic_str]
    j_charged_em = charged_em[basic_str]
    j_neutral_em = neutral_em[basic_str]
    j_charged_had = charged_had[basic_str]
    j_neutral_had = neutral_had[basic_str]
    
    j_em = [x+y for x,y in zip(j_charged_em, j_neutral_em)]
    j_had = [x+y for x,y in zip(j_charged_had, j_neutral_had)]
    
#     j_h_over_e = [x/y for x,y in zip(j_had, j_em)]
    j_h_over_e = []
    for index1, (x,y) in enumerate(zip(j_had, j_em)):
#         print(index1,x,y)
        for index2,(x1,y1) in enumerate(zip(x,y)):
#             print(index2, x1, y1)
            if y1>0:
                j_h_over_e.append(x1/y1)
#         if index>5:
#             break
    
    j_tmf_et = tmf_et[basic_str]
    j_delta_r = delta_r[basic_str]
    j_pt_trk = pt_trk[basic_str]

    #per jet

    j_pt_all = j_pt.flatten()
    j_time_all = j_time.flatten()
    
    j_chef_all = j_charged_had.flatten()
#     j_h_over_e_all = j_h_over_e.flatten()
    j_h_over_e_all = np.array(j_h_over_e)
    
    j_tmf_et_all = j_tmf_et.flatten()
    j_delta_r_all = j_delta_r.flatten()
    j_pt_trk_all = j_pt_trk.flatten()

    # print checkout
    
    print(j_pt_all[:10])
    print(j_time_all[:10])
    
    print(j_chef_all[:10])
    print(j_h_over_e_all[:10])
    
    print(j_tmf_et_all[:10])
    print(j_delta_r_all[:10])
    print(j_pt_trk_all[:10])
    
    # assign 
    
    pf_jet_pt[k] = np.array(j_pt_all)
    pf_jet_time[k] = np.array(j_time_all)
    pf_jet_chef[k] = np.array(j_chef_all)
    pf_jet_tmf_et[k] = np.array(j_tmf_et_all)
    pf_jet_h_over_e[k] = np.array(j_h_over_e_all)
    pf_jet_delta_r[k] = np.array(j_delta_r_all)
    pf_jet_pt_trk[k] = np.array(j_pt_trk_all)

 
    i += 1
# Out:
# /storage/user/jmao/gpu/jmao/cms-llp/plots/20191022/pt_cut_0_match_1_acc_1_acc_case_barrel_acc_or_1/
# W(lv)Jets, background <TTree b'SusyLLPTree' at 0x7fac54dbdef0>
# [23.984398 32.255856 43.39463  31.632086 24.282305 51.037037 25.953854
#  68.92495  55.825153 34.139565]
# [ 0.01224654 -0.7465901  -0.23421304 -0.75142443  0.24839108 -0.19207813
#   3.899583   -0.45693645 -0.6841978  -0.7351578 ]
# [0.27823916 0.6675104  0.38878405 0.09745347 0.44112927 0.03849571
#  0.6941291  0.04291502 0.5632701  0.69896364]
# [0.3855005  2.007613   0.83767956 1.1497937  0.918932   0.22296846
#  3.7823367  0.08623113 2.9977126  2.0125902 ]
# [0.06384943 0.47490194 0.26899672 0.86829835 0.18376368 0.02059972
#  0.29813704 0.02278809 0.4847113  0.6062091 ]
# [0.28262487 0.09107672 0.02550625 0.02038164 0.08575285 0.34778792
#  0.10215771 0.09985186 0.0219605  0.02281572]
# [ 2.776814  27.205477  22.721115  25.241884   5.2274556  1.0191679
#  10.908295   2.4483151 27.66841   21.504242 ]
# W(lv)H(bb), C1N2, 200 GeV, 150 GeV, 1 m <TTree b'SusyLLPTree' at 0x7fac46d32400>
# [ 21.707123 146.04501   20.468678  65.720375  50.774513  28.68922
#   23.622623  62.93441   41.222218  21.48651 ]
# [ 0.73725516 -0.14522573 -0.21048005         nan  1.595784    1.1807626
#   1.0858241   1.7209293  -0.42268652  3.9571044 ]
# [0.39012882 0.00817695 0.01067169 0.03025879 0.04836007 0.04074198
#  0.498469   0.16815203 0.61985385 0.0444571 ]
# [1.2221787e+00 4.5060751e-01 2.8015625e-01 7.1544868e+01 8.4863460e-01
#  4.2472389e-02 1.1237944e+00 1.6992997e+00 2.4874904e+00 1.3700047e+00]
# [0.08972866 0.         0.08035415 0.02106531 0.02640668 0.
#  0.42919755 0.06731728 0.2822971  0.        ]
# [ 0.28593978 15.          0.3603494   0.08624779  0.07301968 15.
#   0.18140498  0.25376248  0.06239334 15.        ]
# [ 3.319552   0.         1.7550226  3.8131776  4.0200453  0.
#  11.470753   5.5548706 16.289557   0.       ]
# W(lv)H(bb), C1N2, 200 GeV, 1 GeV, 1 m <TTree b'SusyLLPTree' at 0x7fac46ae10b8>
# [ 45.119827  82.70494   68.47247   88.43405   99.53325   91.481445
#  115.12559   89.68337   54.89608   54.87077 ]
# [0.47095278 4.339587   0.64416564 0.4228671  1.0414264  0.5699645
#  1.4446647  1.3943523  3.955834   3.330077  ]
# [0.03701913 0.09553626 0.1503637  0.3085804  0.03196168 0.18540543
#  0.03016371 0.13472144 0.06174111 0.10333904]
# [1.1685163  4.4751277  2.0987468  1.2661589  0.7632819  1.0254649
#  2.9064977  1.0269343  0.79836184 1.668025  ]
# [0.02328659 0.04066502 0.06289122 0.0181794  0.         0.02378415
#  0.01658168 0.02973733 0.02789065 0.03287297]
# [0.05188203 0.13712528 0.04120892 0.27674955 0.47998813 0.24130982
#  0.39126095 0.385766   0.08808915 0.2565391 ]
# [ 1.0425482 12.695262  11.426914   2.9460409  0.         2.2017825
#   1.8301662  2.6371765  5.13488    1.7721648]
# W(lv)H(bb), TwinHiggs, 125 GeV, 40 GeV, 1 m <TTree b'SusyLLPTree' at 0x7fac46be70b8>
# [47.09119  31.83119  54.713993 30.585075 67.80436  23.990202 32.77202
#  25.835693 82.07178  31.611084]
# [        nan -0.24056149 -0.45694757  0.8747665   0.2901322   2.6988585
#   0.24823691         nan  0.521294    0.13613069]
# [0.06542389 0.24338138 0.01886856 0.04908401 0.01388071 0.15733877
#  0.         0.01819997 0.05635943 0.57395804]
# [47.46855     0.48469448  0.4590562   0.5653365   0.7863936   0.80888563
#   1.0116067   7.8903475  47.204453    2.6742647 ]
# [0.02632399 0.04027357 0.1516847  0.04071961 0.01873753 0.
#  0.06136395 0.07465062 0.         0.5985192 ]
# [ 0.28586817  0.35027313  0.20849535  0.09521312  0.36842644 15.
#   0.28968754  0.36749187  0.51447815  0.04044425]
# [ 1.2087129  1.1777787  7.6785173  1.1884649  1.2622894  0.
#   1.8991317  1.8432302  0.        19.253136 ]

# %% [markdown]
# ## pf jet pt

# %%
c = rt.TCanvas('c','c', 800, 800)
leg = rt.TLegend(0.33,0.76,0.78,0.94)
leg.SetTextSize(0.022)
leg.SetBorderSize(0)
leg.SetEntrySeparation(0.01)


i = 0
ht = {}


for k,v in tree.items(): 
    print(k,v)
    
    #plotting per jet

    j_gamma_all = pf_jet_pt[k]

    print(j_gamma_all[:10])

    ht[k] = create_TH1D( j_gamma_all, axis_title=['jet Pt [GeV]', 'fraction of events'], name="", binning=[50,-0,2000])
    ht[k].SetLineStyle(stys[k])
    ht[k].SetLineColor(cols[k])
    ht[k].SetMarkerColor(cols[k])
    ht[k].GetXaxis().SetLabelSize(0.03)
    ht[k].GetYaxis().SetLabelSize(0.04)
    ht[k].SetMaximum(1e+3*(ht[k].GetMaximum()))
#     ht[k].SetMaximum(2*(ht[k].GetMaximum()))

    ht[k].DrawNormalized('same')

    leg.AddEntry(ht[k], k)

    i += 1

if match :
    leg.SetHeader('Signal jet matched, pt > ' +str(pt_cut) + ' GeV')
else:
    leg.SetHeader('Signal jet not matched, pt > ' +str(pt_cut) + ' GeV')
    
leg.Draw()

c.SetLogy()
c.SetRightMargin(0.1)
c.Update()
c.Draw()
c.SaveAs(out_dir+'pf_jet_pt_match_'+str(match)+'_pt_cut_'+str(pt_cut)+'.png')
# Out:
# W(lv)Jets, background <TTree b'SusyLLPTree' at 0x7fac54dbdef0>
# [23.984398 32.255856 43.39463  31.632086 24.282305 51.037037 25.953854
#  68.92495  55.825153 34.139565]
# W(lv)H(bb), C1N2, 200 GeV, 150 GeV, 1 m <TTree b'SusyLLPTree' at 0x7fac46d32400>
# [ 21.707123 146.04501   20.468678  65.720375  50.774513  28.68922
#   23.622623  62.93441   41.222218  21.48651 ]
# W(lv)H(bb), C1N2, 200 GeV, 1 GeV, 1 m <TTree b'SusyLLPTree' at 0x7fac46ae10b8>
# [ 45.119827  82.70494   68.47247   88.43405   99.53325   91.481445
#  115.12559   89.68337   54.89608   54.87077 ]
# W(lv)H(bb), TwinHiggs, 125 GeV, 40 GeV, 1 m <TTree b'SusyLLPTree' at 0x7fac46be70b8>
# [47.09119  31.83119  54.713993 30.585075 67.80436  23.990202 32.77202
#  25.835693 82.07178  31.611084]
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /storage/user/jmao/gpu/jmao/cms-llp/plots/20191022/pt_cut_0_match_1_acc_1_acc_case_barrel_acc_or_1/pf_jet_pt_match_1_pt_cut_0.png has been created

# %% [markdown]
# ## pf jet time

# %%
c = rt.TCanvas('c','c', 800, 800)
leg = rt.TLegend(0.33,0.76,0.78,0.94)
leg.SetTextSize(0.022)
leg.SetBorderSize(0)
leg.SetEntrySeparation(0.01)


i = 0
ht = {}


for k,v in tree.items(): 
    print(k,v)
    
    #plotting per jet

    j_gamma_all = pf_jet_time[k]

    print(j_gamma_all[:10])

    ht[k] = create_TH1D( j_gamma_all, axis_title=['jet Time [ns]', 'fraction of events'], name="", binning=[50,-10,20])
    ht[k].SetLineStyle(stys[k])
    ht[k].SetLineColor(cols[k])
    ht[k].SetMarkerColor(cols[k])
    ht[k].GetXaxis().SetLabelSize(0.04)
    ht[k].GetYaxis().SetLabelSize(0.04)
    ht[k].SetMaximum(1e+3*(ht[k].GetMaximum()))

    ht[k].DrawNormalized('same')

    leg.AddEntry(ht[k], k)

    i += 1

if match :
    leg.SetHeader('Signal jet matched, pt > ' +str(pt_cut) + ' GeV')
else:
    leg.SetHeader('Signal jet not matched, pt > ' +str(pt_cut) + ' GeV')
    
leg.Draw()

c.SetLogy()
c.SetRightMargin(0.1)
c.Update()
c.Draw()
c.SaveAs(out_dir+'pf_jet_time_match_'+str(match)+'_pt_cut_'+str(pt_cut)+'.png')
# Out:
# W(lv)Jets, background <TTree b'SusyLLPTree' at 0x7f7a95d19d68>
# [-0.19207813 -0.45693645 -0.6841978  -0.1446694  -0.22283034  0.14651419
#  -0.21933809  0.4203716   0.09519378  0.12266652]
# W(lv)H(bb), C1N2, 200 GeV, 150 GeV, 1 m <TTree b'SusyLLPTree' at 0x7f7aa3feeda0>
# []
# W(lv)H(bb), C1N2, 200 GeV, 1 GeV, 1 m <TTree b'SusyLLPTree' at 0x7f7aa3dc7630>
# []
# W(lv)H(bb), TwinHiggs, 125 GeV, 40 GeV, 1 m <TTree b'SusyLLPTree' at 0x7f7aa40aab70>
# [-0.45694757  0.2901322          nan         nan  0.396022    0.20137274
#          nan  0.95763427  0.6022102          nan]
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Error in <TH1D::DrawNormalized>: Sum of weights is null. Cannot normalize histogram:
# Error in <TH1D::DrawNormalized>: Sum of weights is null. Cannot normalize histogram:
# Info in <TCanvas::Print>: png file /storage/user/jmao/gpu/jmao/cms-llp/plots/20191022/pt_cut_50_match_1_acc_1_acc_case_barrel_acc_or_1/pt_cut_50_match_1_acc_1_acc_case_barrel_acc_or_0/pf_jet_time_match_1_pt_cut_50.png has been created

# %% [markdown]
# ## pf jet track momentum fraction

# %%
c = rt.TCanvas('c','c', 800, 800)
leg = rt.TLegend(0.33,0.76,0.78,0.94)
leg.SetTextSize(0.022)
leg.SetBorderSize(0)
leg.SetEntrySeparation(0.01)


i = 0
ht = {}


for k,v in tree.items(): 
    print(k,v)
    
    #plotting per jet

    j_gamma_all = pf_jet_tmf_et[k]

    print(j_gamma_all[:10])

    ht[k] = create_TH1D( j_gamma_all, axis_title=['jet TMF_{ET max}', 'fraction of events'], name="", binning=[50,-0,2])
    ht[k].SetLineStyle(stys[k])
    ht[k].SetLineColor(cols[k])
    ht[k].SetMarkerColor(cols[k])
    ht[k].GetXaxis().SetLabelSize(0.04)
    ht[k].GetYaxis().SetLabelSize(0.04)
    ht[k].SetMaximum(1e+3*(ht[k].GetMaximum()))

    ht[k].DrawNormalized('same')

    leg.AddEntry(ht[k], k)

    i += 1
    
if match :
    leg.SetHeader('Signal jet matched, pt > ' +str(pt_cut) + ' GeV')
else:
    leg.SetHeader('Signal jet not matched, pt > ' +str(pt_cut) + ' GeV')
    
leg.Draw()

c.SetLogy()
c.SetRightMargin(0.1)
c.Update()
c.Draw()
c.SaveAs(out_dir+'pf_jet_track_momentum_fraction_match_'+str(match)+'_pt_cut_'+str(pt_cut)+'.png')
# Out:
# W(lv)Jets, background <TTree b'SusyLLPTree' at 0x7f7a95d19d68>
# [0.02059972 0.02278809 0.4847113  0.45396155 0.29731095 0.6090283
#  0.7197784  0.11659092 0.34115478 0.6979836 ]
# W(lv)H(bb), C1N2, 200 GeV, 150 GeV, 1 m <TTree b'SusyLLPTree' at 0x7f7aa3feeda0>
# []
# W(lv)H(bb), C1N2, 200 GeV, 1 GeV, 1 m <TTree b'SusyLLPTree' at 0x7f7aa3dc7630>
# []
# W(lv)H(bb), TwinHiggs, 125 GeV, 40 GeV, 1 m <TTree b'SusyLLPTree' at 0x7f7aa40aab70>
# [0.1516847  0.01873753 0.         0.06025455 0.0140099  0.02287168
#  0.         0.         0.03828744 0.03229827]
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Error in <TH1D::DrawNormalized>: Sum of weights is null. Cannot normalize histogram:
# Error in <TH1D::DrawNormalized>: Sum of weights is null. Cannot normalize histogram:
# Info in <TCanvas::Print>: png file /storage/user/jmao/gpu/jmao/cms-llp/plots/20191022/pt_cut_50_match_1_acc_1_acc_case_barrel_acc_or_1/pt_cut_50_match_1_acc_1_acc_case_barrel_acc_or_0/pf_jet_track_momentum_fraction_match_1_pt_cut_50.png has been created

# %% [markdown]
# ## pf jet CHEF

# %%
c = rt.TCanvas('c','c', 800, 800)
leg = rt.TLegend(0.33,0.76,0.78,0.94)
leg.SetTextSize(0.022)
leg.SetBorderSize(0)
leg.SetEntrySeparation(0.01)


i = 0
ht = {}


for k,v in tree.items(): 
    print(k,v)
    
    #plotting per jet

    j_hovere_all = pf_jet_chef[k]

    print(j_hovere_all[:10])

    ht[k] = create_TH1D( j_hovere_all, axis_title=['CHEF', 'fraction of events'], name="", binning=[50,-0,1])
    ht[k].SetLineStyle(stys[k])
    ht[k].SetLineColor(cols[k])
    ht[k].SetMarkerColor(cols[k])
    ht[k].GetXaxis().SetLabelSize(0.04)
    ht[k].GetYaxis().SetLabelSize(0.04)
    ht[k].SetMaximum(10*(ht[k].GetMaximum()))

    ht[k].DrawNormalized('same')

    leg.AddEntry(ht[k], k)

    i += 1

if match :
    leg.SetHeader('Signal jet matched, pt > ' +str(pt_cut) + ' GeV')
else:
    leg.SetHeader('Signal jet not matched, pt > ' +str(pt_cut) + ' GeV')
    
leg.Draw()

c.SetLogy()
c.SetRightMargin(0.1)
c.Update()
c.Draw()
c.SaveAs(out_dir+'pf_jet_chef_match_'+str(match)+'_pt_cut_'+str(pt_cut)+'.png')
# Out:
# W(lv)Jets, background <TTree b'SusyLLPTree' at 0x7f7a95d19d68>
# [0.03849571 0.04291502 0.5632701  0.675664   0.39353418 0.71230024
#  0.7772881  0.87918943 0.41618472 0.7975597 ]
# W(lv)H(bb), C1N2, 200 GeV, 150 GeV, 1 m <TTree b'SusyLLPTree' at 0x7f7aa3feeda0>
# []
# W(lv)H(bb), C1N2, 200 GeV, 1 GeV, 1 m <TTree b'SusyLLPTree' at 0x7f7aa3dc7630>
# []
# W(lv)H(bb), TwinHiggs, 125 GeV, 40 GeV, 1 m <TTree b'SusyLLPTree' at 0x7f7aa40aab70>
# [0.01886856 0.01388071 0.02433043 0.05978422 0.01913191 0.01200524
#  0.16379695 0.01286756 0.03987114 0.06515346]
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Error in <TH1D::DrawNormalized>: Sum of weights is null. Cannot normalize histogram:
# Error in <TH1D::DrawNormalized>: Sum of weights is null. Cannot normalize histogram:
# Info in <TCanvas::Print>: png file /storage/user/jmao/gpu/jmao/cms-llp/plots/20191022/pt_cut_50_match_1_acc_1_acc_case_barrel_acc_or_1/pt_cut_50_match_1_acc_1_acc_case_barrel_acc_or_0/pf_jet_chef_match_1_pt_cut_50.png has been created

# %% [markdown]
# ## pf jet HoverE

# %%
c = rt.TCanvas('c','c', 800, 800)
leg = rt.TLegend(0.33,0.76,0.78,0.94)
leg.SetTextSize(0.022)
leg.SetBorderSize(0)
leg.SetEntrySeparation(0.01)


i = 0
ht = {}


for k,v in tree.items(): 
    print(k,v)
    
    #plotting per jet

    j_hovere_all = pf_jet_h_over_e[k]

    print(j_hovere_all[:10])

    ht[k] = create_TH1D( j_hovere_all, axis_title=['H/E', 'fraction of events'], name="", binning=[50,-0,2])
    ht[k].SetLineStyle(stys[k])
    ht[k].SetLineColor(cols[k])
    ht[k].SetMarkerColor(cols[k])
    ht[k].GetXaxis().SetLabelSize(0.04)
    ht[k].GetYaxis().SetLabelSize(0.04)
    ht[k].SetMaximum(10*(ht[k].GetMaximum()))

    ht[k].DrawNormalized('same')

    leg.AddEntry(ht[k], k)

    i += 1

if match :
    leg.SetHeader('Signal jet matched, pt > ' +str(pt_cut) + ' GeV')
else:
    leg.SetHeader('Signal jet not matched, pt > ' +str(pt_cut) + ' GeV')
    
leg.Draw()

c.SetLogy()
c.SetRightMargin(0.1)
c.Update()
c.Draw()
c.SaveAs(out_dir+'pf_jet_h_over_e_match_'+str(match)+'_pt_cut_'+str(pt_cut)+'.png')
# Out:
# W(lv)Jets, background <TTree b'SusyLLPTree' at 0x7f7a95d19d68>
# [0.22296846 0.08623113 2.9977126  2.4845204  1.9813749  2.8180707
#  3.4901052  7.27742    2.363382   4.190528  ]
# W(lv)H(bb), C1N2, 200 GeV, 150 GeV, 1 m <TTree b'SusyLLPTree' at 0x7f7aa3feeda0>
# []
# W(lv)H(bb), C1N2, 200 GeV, 1 GeV, 1 m <TTree b'SusyLLPTree' at 0x7f7aa3dc7630>
# []
# W(lv)H(bb), TwinHiggs, 125 GeV, 40 GeV, 1 m <TTree b'SusyLLPTree' at 0x7f7aa40aab70>
# [ 0.4590562  0.7863936 66.8707    88.320335   1.8628672  0.2311049
#  41.289856   0.8704772  0.8028408 26.68995  ]
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Error in <TH1D::DrawNormalized>: Sum of weights is null. Cannot normalize histogram:
# Error in <TH1D::DrawNormalized>: Sum of weights is null. Cannot normalize histogram:
# Info in <TCanvas::Print>: png file /storage/user/jmao/gpu/jmao/cms-llp/plots/20191022/pt_cut_50_match_1_acc_1_acc_case_barrel_acc_or_1/pt_cut_50_match_1_acc_1_acc_case_barrel_acc_or_0/pf_jet_h_over_e_match_1_pt_cut_50.png has been created

# %% [markdown]
# ## pf jet pt tracks

# %%
c = rt.TCanvas('c','c', 800, 800)
leg = rt.TLegend(0.33,0.76,0.78,0.94)
leg.SetTextSize(0.022)
leg.SetBorderSize(0)
leg.SetEntrySeparation(0.01)


i = 0
ht = {}


for k,v in tree.items(): 
    print(k,v)
    
    #plotting per jet

    j_hovere_all = pf_jet_pt_trk[k]

    print(j_hovere_all[:10])

    ht[k] = create_TH1D( j_hovere_all, axis_title=['Pt_{tracks #in PV } [GeV]', 'fraction of events'], name="", binning=[50,-0,100])
    ht[k].SetLineStyle(stys[k])
    ht[k].SetLineColor(cols[k])
    ht[k].SetMarkerColor(cols[k])
    ht[k].GetXaxis().SetLabelSize(0.04)
    ht[k].GetYaxis().SetLabelSize(0.04)
    ht[k].SetMaximum(10*(ht[k].GetMaximum()))

    ht[k].DrawNormalized('same')

    leg.AddEntry(ht[k], k)

    i += 1

if match :
    leg.SetHeader('Signal jet matched, pt > ' +str(pt_cut) + ' GeV')
else:
    leg.SetHeader('Signal jet not matched, pt > ' +str(pt_cut) + ' GeV')
    
leg.Draw()

c.SetLogy()
c.SetRightMargin(0.1)
c.Update()
c.Draw()
c.SaveAs(out_dir+'pf_jet_pt_trk_match_'+str(match)+'_pt_cut_'+str(pt_cut)+'.png')
# Out:
# W(lv)Jets, background <TTree b'SusyLLPTree' at 0x7f7a95d19d68>
# [ 1.0191679  2.4483151 27.66841   25.610815  28.593454  42.433662
#  45.762962  10.256428  39.329277  64.398026 ]
# W(lv)H(bb), C1N2, 200 GeV, 150 GeV, 1 m <TTree b'SusyLLPTree' at 0x7f7aa3feeda0>
# []
# W(lv)H(bb), C1N2, 200 GeV, 1 GeV, 1 m <TTree b'SusyLLPTree' at 0x7f7aa3dc7630>
# []
# W(lv)H(bb), TwinHiggs, 125 GeV, 40 GeV, 1 m <TTree b'SusyLLPTree' at 0x7f7aa40aab70>
# [7.6785173 1.2622894 0.        8.979916  4.6266885 2.5538588 0.
#  0.        3.4947233 4.0802093]
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Error in <TH1D::DrawNormalized>: Sum of weights is null. Cannot normalize histogram:
# Error in <TH1D::DrawNormalized>: Sum of weights is null. Cannot normalize histogram:
# Info in <TCanvas::Print>: png file /storage/user/jmao/gpu/jmao/cms-llp/plots/20191022/pt_cut_50_match_1_acc_1_acc_case_barrel_acc_or_1/pt_cut_50_match_1_acc_1_acc_case_barrel_acc_or_0/pf_jet_pt_trk_match_1_pt_cut_50.png has been created

# %% [markdown]
# ## pf jet delta R

# %%
c = rt.TCanvas('c','c', 800, 800)
leg = rt.TLegend(0.33,0.76,0.78,0.94)
leg.SetTextSize(0.022)
leg.SetBorderSize(0)
leg.SetEntrySeparation(0.01)


i = 0
ht = {}


for k,v in tree.items(): 
    print(k,v)
    
    #plotting per jet

    j_hovere_all = pf_jet_delta_r[k]

    print(j_hovere_all[:10])

    ht[k] = create_TH1D( j_hovere_all, axis_title=['#Delta R_{min}', 'fraction of events'], name="", binning=[50,-0,2])
    ht[k].SetLineStyle(stys[k])
    ht[k].SetLineColor(cols[k])
    ht[k].SetMarkerColor(cols[k])
    ht[k].GetXaxis().SetLabelSize(0.04)
    ht[k].GetYaxis().SetLabelSize(0.04)
    ht[k].SetMaximum(10*(ht[k].GetMaximum()))

    ht[k].DrawNormalized('same')

    leg.AddEntry(ht[k], k)

    i += 1

if match :
    leg.SetHeader('Signal jet matched, pt > ' +str(pt_cut) + ' GeV')
else:
    leg.SetHeader('Signal jet not matched, pt > ' +str(pt_cut) + ' GeV')
    
leg.Draw()

c.SetLogy()
c.SetRightMargin(0.1)
c.Update()
c.Draw()
c.SaveAs(out_dir+'pf_jet_delta_r_match_'+str(match)+'_pt_cut_'+str(pt_cut)+'.png')
# Out:
# W(lv)Jets, background <TTree b'SusyLLPTree' at 0x7f7a95d19d68>
# [0.34778792 0.09985186 0.0219605  0.01970636 0.02013182 0.07952045
#  0.02773485 0.04309382 0.04823545 0.02409377]
# W(lv)H(bb), C1N2, 200 GeV, 150 GeV, 1 m <TTree b'SusyLLPTree' at 0x7f7aa3feeda0>
# []
# W(lv)H(bb), C1N2, 200 GeV, 1 GeV, 1 m <TTree b'SusyLLPTree' at 0x7f7aa3dc7630>
# []
# W(lv)H(bb), TwinHiggs, 125 GeV, 40 GeV, 1 m <TTree b'SusyLLPTree' at 0x7f7aa40aab70>
# [2.0849535e-01 3.6842644e-01 1.5000000e+01 2.9161611e-01 1.1737422e-01
#  3.2878995e-01 4.4154799e-01 4.0404058e-01 6.9181398e-03 1.4711516e-01]
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Error in <TH1D::DrawNormalized>: Sum of weights is null. Cannot normalize histogram:
# Error in <TH1D::DrawNormalized>: Sum of weights is null. Cannot normalize histogram:
# Info in <TCanvas::Print>: png file /storage/user/jmao/gpu/jmao/cms-llp/plots/20191022/pt_cut_50_match_1_acc_1_acc_case_barrel_acc_or_1/pt_cut_50_match_1_acc_1_acc_case_barrel_acc_or_0/pf_jet_delta_r_match_1_pt_cut_50.png has been created

# %% [markdown]
# # pf jet ROC

# %%
### ROC curve
var_pf = [pf_jet_delta_r, pf_jet_h_over_e, pf_jet_chef, pf_jet_tmf_et ]
axis_pf = [['PFJet PV tracks #Delta R_{min}','Events'], ['H/E','Events'],['CHEF','Events'],['PFJet TMF_{MAX}','Events']  ]
name_pf = ['pfjetMinDeltaRPVTracks','HoverE','CHEF','pfjetGammaMax_ET'  ]
bins_pf = [[50,0,10],[50,0,1.5],[50,0,1.5],[50,0,1.5],[50,0,10]]
maxs_pf = [10, 50, 1.5, 1.5, 1.5]

sig_keys = ['W(lv)H(bb), TwinHiggs, 125 GeV, 40 GeV, 1 m',]
# sig_keys = ['W(lv)H(bb), TwinHiggs, 125 GeV, 40 GeV, 1 m', 'W(lv)H(bb), C1N2, 200 GeV, 150 GeV, 1 m', 'W(lv)H(bb), C1N2, 200 GeV, 1 GeV, 1 m',]
qcd_key = 'W(lv)Jets, background'
calo = 0
for sig_k in sig_keys:
    c = rt.TCanvas('c','c', 800, 800)
    leg = rt.TLegend(0.68,0.19,0.86,0.34)
    leg.SetTextSize(0.022)
    leg.SetBorderSize(0)
    leg.SetEntrySeparation(0.01)
    gr = {}
    purity = {}
    if calo:
        var = var_calo
        name = name_calo
        axis = axis_calo
        maxs = maxs_calo
    else:
        var = var_pf
        name = name_pf
        axis = axis_pf
        maxs = maxs_pf
    for i in range(len(var)):
        v = var[i]
        eff = {}
        thre = maxs[i]*np.array(range(1,1000))/1000.0
#         print(np.max(thre),np.min(thre))
        print(name[i])
        for k in tree.keys():
            v = var[i][k]
            print(k,len(v))
            if len(v)==0:
                print('no')
                eff[k] = []
                for th in thre:
                    if 'MinDeltaR' in name[i]:
                        eff[k].append(1.0)
                    else:
                        eff[k].append(1.0)
                eff[k] = np.array(eff[k])
            else:
                eff[k] = []
                for th in thre:
                    if 'MinDeltaR' in name[i]:
                        eff[k].append(1.0*np.count_nonzero(v>th)/len(v))
                    else:
                        eff[k].append(1.0*np.count_nonzero(v<th)/len(v))
                eff[k] = np.array(eff[k])
    #     Plotting ROC curve
        gr[name[i]] = create_TGraph(eff[qcd_key],eff[sig_k],axis_title = ['#epsilon_{bkg}','#epsilon_{signal}'])
        print(len(eff[qcd_key]))
        print(eff[qcd_key][:10])
        print(min(eff[qcd_key]))
        print(max(eff[qcd_key]))
        print(min(eff[qcd_key]))
        print(eff[sig_k][:10])
        print(min(eff[sig_k]))
        print(max(eff[sig_k]))
        gr[name[i]].SetLineColor(std_color_list[i])
        gr[name[i]].SetLineWidth(2)
        gr[name[i]].GetYaxis().SetRangeUser(0.0, 1.0)
        gr[name[i]].GetXaxis().SetLimits(0.0, 1.0)

        leg.AddEntry(gr[name[i]],axis[i][0])

        gr[name[i]].Draw('ac' if i==0 else 'c')

    if match :
        leg.SetHeader('Signal jet matched, pt > ' +str(pt_cut) + ' GeV')
    else:
        leg.SetHeader('Signal jet not matched, pt > ' +str(pt_cut) + ' GeV')

    leg.Draw()
#     c.SetLogx()
    c.Draw()
    c.SaveAs(out_dir+sig_k+'_pfROC_match_'+str(match)+'_pt_cut_'+str(pt_cut)+'.png')
# Out:
# pfjetMinDeltaRPVTracks
# W(lv)Jets, background 165086
# W(lv)H(bb), C1N2, 200 GeV, 150 GeV, 1 m 0
# no
# W(lv)H(bb), C1N2, 200 GeV, 1 GeV, 1 m 0
# no
# W(lv)H(bb), TwinHiggs, 125 GeV, 40 GeV, 1 m 1129
# 999
# [0.89204415 0.69792108 0.52303042 0.38764644 0.2895824  0.21944926
#  0.17034152 0.13436027 0.10778019 0.08841452]
# 0.0010115939570890325
# 0.8920441466871812
# 0.0010115939570890325
# [0.9955713  0.99202834 0.98582817 0.97962799 0.96722764 0.95039858
#  0.93888397 0.92559787 0.90434012 0.87776794]
# 0.1355181576616475
# 0.995571302037201
# HoverE
# W(lv)Jets, background 164651
# W(lv)H(bb), C1N2, 200 GeV, 150 GeV, 1 m 0
# no
# W(lv)H(bb), C1N2, 200 GeV, 1 GeV, 1 m 0
# no
# W(lv)H(bb), TwinHiggs, 125 GeV, 40 GeV, 1 m 1099
# 999
# [0.01048885 0.02147573 0.03190992 0.04108691 0.04952293 0.0574913
#  0.06459724 0.07188538 0.07955615 0.08735446]
# 0.010488852178243678
# 0.9889645371118305
# 0.010488852178243678
# [0.00181984 0.0100091  0.0200182  0.03457689 0.05095541 0.07097361
#  0.09281165 0.11191993 0.13921747 0.17652411]
# 0.0018198362147406734
# 0.89171974522293
# CHEF
# W(lv)Jets, background 165086
# W(lv)H(bb), C1N2, 200 GeV, 150 GeV, 1 m 0
# no
# W(lv)H(bb), C1N2, 200 GeV, 1 GeV, 1 m 0
# no
# W(lv)H(bb), TwinHiggs, 125 GeV, 40 GeV, 1 m 1129
# 999
# [0.0025199  0.00268951 0.00307113 0.00364053 0.00437954 0.00509431
#  0.00592418 0.00668742 0.00740826 0.00817756]
# 0.0025198987194553144
# 1.0
# 0.0025198987194553144
# [0.05225864 0.05934455 0.0806023  0.10008857 0.11868911 0.1319752
#  0.15146147 0.15854739 0.18246236 0.20372011]
# 0.05225863596102746
# 1.0
# pfjetGammaMax_ET
# W(lv)Jets, background 165086
# W(lv)H(bb), C1N2, 200 GeV, 150 GeV, 1 m 0
# no
# W(lv)H(bb), C1N2, 200 GeV, 1 GeV, 1 m 0
# no
# W(lv)H(bb), TwinHiggs, 125 GeV, 40 GeV, 1 m 1129
# 999
# [0.00862581 0.00862581 0.00865004 0.00866215 0.00871061 0.00886205
#  0.00903771 0.0093103  0.00958894 0.01011594]
# 0.008625807155058576
# 0.9996971275577577
# 0.008625807155058576
# [0.25686448 0.25686448 0.25686448 0.25863596 0.26129318 0.26572188
#  0.27635075 0.29672276 0.32506643 0.36138175]
# 0.25686448184233834
# 1.0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /storage/user/jmao/gpu/jmao/cms-llp/plots/20191022/pt_cut_50_match_1_acc_1_acc_case_barrel_acc_or_1/pt_cut_50_match_1_acc_1_acc_case_barrel_acc_or_0/W(lv)H(bb), TwinHiggs, 125 GeV, 40 GeV, 1 m_pfROC_match_1_pt_cut_50.png has been created
